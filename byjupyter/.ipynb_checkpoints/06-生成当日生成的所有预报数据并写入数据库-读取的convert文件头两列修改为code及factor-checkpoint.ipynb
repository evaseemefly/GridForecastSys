# %%
import numpy as np
import pandas as pd
import os
import sys
import datetime

# %%
# read_date=pd.read_csv('convert_date.csv',',')
read_date=pd.read_csv('convert_data20180520.csv',',')
# read_date=read_date.set_index([0,1])
read_date.head()
# Out:
#   code factor  2018-05-20 08:00  2018-05-20 09:00  2018-05-20 10:00  \
# 0  N01     HS              0.48              0.48              0.48
# 1  N01    PER              4.02              4.03              4.05
# 2  N01    DIR             23.54             23.60             23.82
# 3  N02     HS              0.42              0.42              0.41
# 4  N02    PER              4.71              4.68              4.61
#
#    2018-05-20 11:00  2018-05-20 12:00  2018-05-20 13:00  2018-05-20 14:00  \
# 0              0.48              0.48              0.48              0.47
# 1              4.07              4.10              4.12              4.13
# 2             24.03             24.11             24.05             23.88
# 3              0.41              0.42              0.44              0.47
# 4              4.51              4.31              4.02              3.68
#
#    2018-05-20 15:00        ...         2018-05-22 23:00  2018-05-23 00:00  \
# 0              0.47        ...                     0.31              0.30
# 1              4.15        ...                     5.11              5.10
# 2             23.62        ...                    16.02             15.88
# 3              0.50        ...                     0.30              0.29
# 4              3.58        ...                     5.48              5.67
#
#    2018-05-23 01:00  2018-05-23 02:00  2018-05-23 03:00  2018-05-23 04:00  \
# 0              0.29              0.29              0.28              0.28
# 1              5.11              5.13              5.04              4.93
# 2             15.78             15.70             15.55             15.37
# 3              0.28              0.27              0.26              0.26
# 4              5.96              6.30              6.33              6.26
#
#    2018-05-23 05:00  2018-05-23 06:00  2018-05-23 07:00  2018-05-23 08:00
# 0              0.27              0.27              0.26              0.26
# 1              4.83              4.70              4.60              4.47
# 2             15.16             14.85             14.50             13.94
# 3              0.26              0.25              0.25              0.25
# 4              6.15              6.23              6.38              6.49
#
# [5 rows x 75 columns]

# %%
read_date=pd.read_csv('convert_data20180520.csv', sep=',', encoding='utf-8', infer_datetime_format=True)
read_date
# Out:
#     code factor  2018-05-20 08:00  2018-05-20 09:00  2018-05-20 10:00  \
# 0    N01     HS              0.48              0.48              0.48
# 1    N01    PER              4.02              4.03              4.05
# 2    N01    DIR             23.54             23.60             23.82
# 3    N02     HS              0.42              0.42              0.41
# 4    N02    PER              4.71              4.68              4.61
# 5    N02    DIR            352.89            352.99            353.43
# 6    N03     HS              0.39              0.39              0.36
# 7    N03    PER              2.73              2.74              2.78
# 8    N03    DIR             38.80             41.50             41.60
# 9    N04     HS              0.80              0.78              0.75
# 10   N04    PER              4.02              4.05              4.10
# 11   N04    DIR             20.20             20.27             19.46
# 12   N05     HS              1.16              1.13              1.10
# 13   N05    PER              4.45              4.46              4.48
# 14   N05    DIR             21.47             20.64             19.22
# 15   N06     HS              0.96              0.93              0.88
# 16   N06    PER              4.21              4.20              4.22
# 17   N06    DIR             10.16             10.26              9.26
# 18   N07     HS              0.55              0.52              0.49
# 19   N07    PER              3.94              4.01              4.07
# 20   N07    DIR              5.35              3.78              1.91
# 21   N08     HS              0.93              0.89              0.84
# 22   N08    PER              4.07              4.11              4.14
# 23   N08    DIR             27.27             27.47             27.11
# 24   N09     HS              0.99              0.92              0.84
# 25   N09    PER              4.07              4.07              4.04
# 26   N09    DIR             46.26             46.35             45.99
# 27   N10     HS              0.92              0.85              0.79
# 28   N10    PER              3.71              3.69              3.66
# 29   N10    DIR             50.37             50.92             51.51
# ..   ...    ...               ...               ...               ...
# 609  S42     HS              0.60              0.65              0.71
# 610  S42    PER              6.17              6.41              6.64
# 611  S42    DIR            192.99            191.78            214.82
# 612  S43     HS              0.29              0.29              0.29
# 613  S43    PER              3.73              3.81              3.91
# 614  S43    DIR            320.86            318.73            316.54
# 615  S44     HS              0.32              0.33              0.34
# 616  S44    PER              3.55              3.61              3.61
# 617  S44    DIR            339.26            342.27            343.91
# 618  S45     HS              0.13              0.13              0.14
# 619  S45    PER              3.39              3.47              3.60
# 620  S45    DIR             16.83             18.00             19.28
# 621  S46     HS              0.09              0.09              0.09
# 622  S46    PER              3.63              3.73              3.76
# 623  S46    DIR             29.22             25.61             19.16
# 624  S47     HS              0.11              0.10              0.10
# 625  S47    PER              3.08              3.07              3.06
# 626  S47    DIR            235.06            235.98            236.88
# 627  S48     HS              0.17              0.15              0.15
# 628  S48    PER              3.34              3.84              4.33
# 629  S48    DIR             92.72            180.68            219.01
# 630  S49     HS              0.22              0.22              0.23
# 631  S49    PER              4.86              5.00              5.08
# 632  S49    DIR            239.95            239.05            238.51
# 633  S50     HS              0.59              0.58              0.58
# 634  S50    PER              5.25              5.33              5.40
# 635  S50    DIR            232.67            232.63            232.56
# 636  S51     HS              1.27              1.26              1.26
# 637  S51    PER              6.20              6.28              6.32
# 638  S51    DIR            265.27            265.51            261.27
#
#      2018-05-20 11:00  2018-05-20 12:00  2018-05-20 13:00  2018-05-20 14:00  \
# 0                0.48              0.48              0.48              0.47
# 1                4.07              4.10              4.12              4.13
# 2               24.03             24.11             24.05             23.88
# 3                0.41              0.42              0.44              0.47
# 4                4.51              4.31              4.02              3.68
# 5              354.00            355.44            357.96              1.24
# 6                0.31              0.26              0.24              0.23
# 7                2.89              3.05              3.19              3.24
# 8               38.34             32.53             25.73             19.79
# 9                0.71              0.68              0.67              0.68
# 10               4.15              4.12              3.98              3.82
# 11              17.91             17.01             16.97             16.96
# 12               1.07              1.04              1.02              1.01
# 13               4.51              4.50              4.44              4.37
# 14              17.41             16.22             15.98             16.31
# 15               0.84              0.79              0.75              0.70
# 16               4.25              4.28              4.32              4.35
# 17               7.40              5.17              2.68              0.10
# 18               0.46              0.44              0.41              0.38
# 19               4.12              4.14              4.13              4.11
# 20             359.99            358.17            356.63            355.25
# 21               0.79              0.73              0.68              0.62
# 22               4.15              4.15              4.14              4.12
# 23              26.22             24.92             23.36             21.78
# 24               0.77              0.70              0.64              0.58
# 25               4.02              3.99              3.94              3.89
# 26              45.62             45.63             46.01             46.49
# 27               0.73              0.67              0.62              0.57
# 28               3.64              3.61              3.57              3.53
# 29              52.31             53.29             54.31             55.38
# ..                ...               ...               ...               ...
# 609              0.77              0.83              0.89              0.93
# 610              6.84              6.99              7.11              7.19
# 611            214.28            215.52            235.23            235.04
# 612              0.29              0.30              0.31              0.32
# 613              4.04              4.17              4.28              4.33
# 614            314.35            311.98            309.75            308.31
# 615              0.35              0.36              0.38              0.42
# 616              3.55              3.42              3.24              3.06
# 617            344.69            344.20            342.84            341.68
# 618              0.15              0.17              0.18              0.20
# 619              3.76              3.89              3.98              3.92
# 620             20.62             21.87             22.90             23.75
# 621              0.09              0.09              0.09              0.10
# 622              3.75              3.73              3.78              3.45
# 623             15.45             17.71             22.53             50.78
# 624              0.09              0.09              0.08              0.07
# 625              3.04              3.04              3.08              3.16
# 626            236.91            236.31            235.52            235.12
# 627              0.15              0.15              0.15              0.15
# 628              4.70              4.92              5.04              5.09
# 629            259.32            259.12            259.17            259.27
# 630              0.22              0.22              0.22              0.21
# 631              5.11              5.13              5.15              5.19
# 632            238.28            238.14            238.03            237.92
# 633              0.57              0.56              0.56              0.56
# 634              5.46              5.48              5.45              5.34
# 635            232.49            232.55            232.72            233.07
# 636              1.25              1.24              1.23              1.23
# 637              6.34              6.32              6.26              6.17
# 638            261.43            256.86            247.94            235.38
#
#      2018-05-20 15:00        ...         2018-05-22 23:00  2018-05-23 00:00  \
# 0                0.47        ...                     0.31              0.30
# 1                4.15        ...                     5.11              5.10
# 2               23.62        ...                    16.02             15.88
# 3                0.50        ...                     0.30              0.29
# 4                3.58        ...                     5.48              5.67
# 5                2.21        ...                   336.16            337.34
# 6                0.24        ...                     0.13              0.13
# 7                3.04        ...                     5.66              5.58
# 8               20.06        ...                   358.99            358.08
# 9                0.69        ...                     0.36              0.35
# 10               3.67        ...                     5.77              5.67
# 11              17.46        ...                   350.77            350.24
# 12               0.99        ...                     0.60              0.69
# 13               4.32        ...                     4.76              3.77
# 14              16.30        ...                   342.67            340.69
# 15               0.66        ...                     0.41              0.40
# 16               4.35        ...                     6.33              6.29
# 17             358.21        ...                   335.72            335.66
# 18               0.36        ...                     0.21              0.20
# 19               4.08        ...                     6.07              6.22
# 20             353.97        ...                   334.67            335.39
# 21               0.57        ...                     0.27              0.26
# 22               4.09        ...                     5.16              5.27
# 23              20.13        ...                   323.68            324.03
# 24               0.52        ...                     0.20              0.19
# 25               3.83        ...                     4.24              4.26
# 26              46.81        ...                   310.47            310.01
# 27               0.52        ...                     0.25              0.22
# 28               3.48        ...                     3.11              3.08
# 29              56.48        ...                   156.92            161.99
# ..                ...        ...                      ...               ...
# 609              0.97        ...                     0.87              0.89
# 610              7.25        ...                     4.95              4.83
# 611            234.93        ...                   313.56            315.95
# 612              0.33        ...                     0.59              0.60
# 613              4.39        ...                     4.42              4.28
# 614            306.49        ...                   335.42            336.99
# 615              0.46        ...                     0.54              0.55
# 616              2.99        ...                     3.80              3.74
# 617            340.60        ...                   353.42            352.43
# 618              0.22        ...                     0.52              0.53
# 619              3.61        ...                     3.02              3.05
# 620             24.10        ...                    25.28             22.12
# 621              0.10        ...                     0.56              0.54
# 622              3.76        ...                     3.51              3.44
# 623             40.99        ...                    42.35             40.70
# 624              0.07        ...                     0.62              0.55
# 625              3.27        ...                     3.79              3.76
# 626            214.24        ...                    62.69             62.86
# 627              0.14        ...                     0.53              0.49
# 628              5.10        ...                     4.09              4.08
# 629            259.37        ...                    81.68             81.88
# 630              0.21        ...                     0.33              0.32
# 631              5.22        ...                     3.95              3.91
# 632            237.83        ...                    94.73             95.49
# 633              0.57        ...                     0.33              0.33
# 634              5.11        ...                     5.38              5.31
# 635            233.76        ...                   160.94            167.93
# 636              1.23        ...                     0.87              0.83
# 637              6.04        ...                     4.82              4.97
# 638            214.04        ...                   301.09            304.10
#
#      2018-05-23 01:00  2018-05-23 02:00  2018-05-23 03:00  2018-05-23 04:00  \
# 0                0.29              0.29              0.28              0.28
# 1                5.11              5.13              5.04              4.93
# 2               15.78             15.70             15.55             15.37
# 3                0.28              0.27              0.26              0.26
# 4                5.96              6.30              6.33              6.26
# 5              338.55            339.70            339.72            338.93
# 6                0.13              0.13              0.12              0.12
# 7                5.54              5.52              5.46              5.41
# 8              357.72            357.76            357.24            356.19
# 9                0.34              0.34              0.33              0.33
# 10               5.64              5.63              5.57              5.47
# 11             350.13            349.94            348.29            345.36
# 12               0.70              0.67              0.65              0.63
# 13               4.04              4.22              4.26              4.23
# 14             325.23            329.08            314.87            317.24
# 15               0.39              0.38              0.38              0.37
# 16               6.26              6.24              6.28              6.34
# 17             335.62            335.60            335.68            335.71
# 18               0.19              0.19              0.19              0.18
# 19               6.31              6.38              6.44              6.51
# 20             335.84            336.13            336.38            336.64
# 21               0.25              0.24              0.24              0.23
# 22               5.45              5.63              5.78              5.90
# 23             324.90            325.87            326.61            327.09
# 24               0.17              0.17              0.16              0.15
# 25               4.31              4.37              4.43              4.52
# 26             309.99            310.28            310.72            311.23
# 27               0.20              0.18              0.17              0.18
# 28               3.07              3.05              3.02              3.01
# 29             158.96            163.67            165.84            158.48
# ..                ...               ...               ...               ...
# 609              0.90              0.91              0.91              0.91
# 610              4.84              4.87              4.91              4.95
# 611            317.12            317.50            317.38            317.15
# 612              0.62              0.64              0.65              0.66
# 613              4.20              4.18              4.19              4.23
# 614            338.59            339.46            339.61            339.55
# 615              0.55              0.55              0.55              0.55
# 616              3.80              3.88              3.94              3.97
# 617            352.72            353.13            353.20            353.36
# 618              0.53              0.52              0.50              0.49
# 619              3.07              3.06              3.03              3.01
# 620             19.85             18.06             17.36             17.47
# 621              0.55              0.58              0.61              0.59
# 622              3.34              3.28              3.34              3.44
# 623             37.00             32.78             31.57             32.43
# 624              0.50              0.46              0.43              0.42
# 625              3.71              3.64              3.64              3.72
# 626             62.54             62.02             62.14             62.52
# 627              0.45              0.41              0.37              0.34
# 628              4.05              4.00              3.94              3.88
# 629             81.96             82.02             82.10             82.24
# 630              0.30              0.28              0.26              0.24
# 631              3.88              3.84              3.81              3.76
# 632             96.17             96.84             97.62             98.58
# 633              0.33              0.32              0.31              0.30
# 634              5.29              5.32              5.37              5.44
# 635            167.23            179.13            203.34            205.82
# 636              0.81              0.80              0.79              0.77
# 637              5.06              5.10              5.22              5.44
# 638            302.91            302.47            301.49            302.82
#
#      2018-05-23 05:00  2018-05-23 06:00  2018-05-23 07:00  2018-05-23 08:00
# 0                0.27              0.27              0.26              0.26
# 1                4.83              4.70              4.60              4.47
# 2               15.16             14.85             14.50             13.94
# 3                0.26              0.25              0.25              0.25
# 4                6.15              6.23              6.38              6.49
# 5              337.66            337.76            338.38            338.25
# 6                0.12              0.12              0.12              0.12
# 7                5.30              5.38              5.45              5.57
# 8              353.15            351.61            332.13            332.57
# 9                0.33              0.32              0.32              0.31
# 10               5.42              5.53              5.71              5.91
# 11             343.97            344.35            345.39            346.47
# 12               0.62              0.62              0.62              0.61
# 13               4.18              4.15              4.17              4.25
# 14             317.56            316.64            303.12            305.60
# 15               0.37              0.37              0.37              0.38
# 16               6.38              6.34              6.27              6.29
# 17             335.28            333.89            332.03            331.41
# 18               0.18              0.18              0.18              0.19
# 19               6.59              6.67              6.70              6.59
# 20             336.93            337.16            336.71            334.93
# 21               0.23              0.23              0.25              0.27
# 22               5.98              5.87              5.45              5.02
# 23             327.17            324.75            317.50            309.04
# 24               0.14              0.14              0.13              0.13
# 25               4.64              4.78              4.92              5.02
# 26             311.78            312.35            312.83            315.62
# 27               0.20              0.22              0.22              0.21
# 28               2.99              2.99              3.00              3.03
# 29             140.78            139.41            151.71            151.41
# ..                ...               ...               ...               ...
# 609              0.91              0.90              0.90              0.90
# 610              5.00              5.04              5.07              5.09
# 611            317.14            317.58            318.55            319.89
# 612              0.67              0.68              0.69              0.70
# 613              4.27              4.32              4.38              4.43
# 614            339.72            340.34            341.26            342.17
# 615              0.55              0.55              0.57              0.59
# 616              4.00              4.02              4.06              4.11
# 617            353.79            354.44            355.46            356.61
# 618              0.47              0.46              0.47              0.48
# 619              3.00              2.98              2.97              2.97
# 620             18.29             18.65             18.84             18.97
# 621              0.56              0.52              0.50              0.49
# 622              3.51              3.52              3.48              3.46
# 623             33.98             34.76             35.09             35.49
# 624              0.42              0.43              0.42              0.39
# 625              3.84              3.95              4.00              3.97
# 626             62.45             61.74             60.71             59.88
# 627              0.31              0.29              0.28              0.28
# 628              3.84              3.85              3.93              4.04
# 629             82.36             82.30             81.80             80.76
# 630              0.22              0.21              0.19              0.18
# 631              3.72              3.69              3.68              3.69
# 632             99.76            101.14            102.70            104.29
# 633              0.29              0.29              0.28              0.27
# 634              5.51              5.58              5.65              5.71
# 635            219.96            221.82            223.44            224.75
# 636              0.74              0.72              0.70              0.69
# 637              5.71              5.92              6.07              6.18
# 638            300.61            304.58            303.17            301.98
#
# [639 rows x 75 columns]

# %% [markdown]
# #### 1对调code和facotr列

# %% [markdown]
# ##### 1.1 获取所有的columns

# %%
cols = list(read_date)
cols[:5]
# Out:
# ['code', 'factor', '2018-05-20 08:00', '2018-05-20 09:00', '2018-05-20 10:00']

# %% [markdown]
# ##### 1.2 获取'1'（factor）的所在位置，并移至第一列

# %% [markdown]
# * list.pop 用于移除列表中的一个元素（默认最后一个元素），并且返回该元素的值。

# %%
cols.index('factor')
# Out:
# 1

# %%
# cols.insert(0, cols.pop(cols.index('1')))
cols.insert(0, cols.pop(cols.index('factor')))

# %%
cols[:5]
# Out:
# ['factor', 'code', '2018-05-20 08:00', '2018-05-20 09:00', '2018-05-20 10:00']

# %%
# read_date.index

# %% [markdown]
# * 找到所有的HS的列

# %%
# read_date=read_date.set_index([1,0])
read_date=read_date.set_index(['factor','code'])

# %%
read_date.T.head()
# Out:
# factor              HS   PER    DIR    HS   PER     DIR    HS   PER    DIR  \
# code               N01   N01    N01   N02   N02     N02   N03   N03    N03
# 2018-05-20 08:00  0.48  4.02  23.54  0.42  4.71  352.89  0.39  2.73  38.80
# 2018-05-20 09:00  0.48  4.03  23.60  0.42  4.68  352.99  0.39  2.74  41.50
# 2018-05-20 10:00  0.48  4.05  23.82  0.41  4.61  353.43  0.36  2.78  41.60
# 2018-05-20 11:00  0.48  4.07  24.03  0.41  4.51  354.00  0.31  2.89  38.34
# 2018-05-20 12:00  0.48  4.10  24.11  0.42  4.31  355.44  0.26  3.05  32.53
#
# factor              HS   ...       DIR    HS   PER     DIR    HS   PER  \
# code               N04   ...       S48   S49   S49     S49   S50   S50
# 2018-05-20 08:00  0.80   ...     92.72  0.22  4.86  239.95  0.59  5.25
# 2018-05-20 09:00  0.78   ...    180.68  0.22  5.00  239.05  0.58  5.33
# 2018-05-20 10:00  0.75   ...    219.01  0.23  5.08  238.51  0.58  5.40
# 2018-05-20 11:00  0.71   ...    259.32  0.22  5.11  238.28  0.57  5.46
# 2018-05-20 12:00  0.68   ...    259.12  0.22  5.13  238.14  0.56  5.48
#
# factor               DIR    HS   PER     DIR
# code                 S50   S51   S51     S51
# 2018-05-20 08:00  232.67  1.27  6.20  265.27
# 2018-05-20 09:00  232.63  1.26  6.28  265.51
# 2018-05-20 10:00  232.56  1.26  6.32  261.27
# 2018-05-20 11:00  232.49  1.25  6.34  261.43
# 2018-05-20 12:00  232.55  1.24  6.32  256.86
#
# [5 rows x 639 columns]

# %%
# read_date.T['HS',:]
df_convert_1=read_date.T['HS']
df_convert_1.head()
# Out:
# code               N01   N02   N03   N04   N05   N06   N07   N08   N09   N10  \
# 2018-05-20 08:00  0.48  0.42  0.39  0.80  1.16  0.96  0.55  0.93  0.99  0.92
# 2018-05-20 09:00  0.48  0.42  0.39  0.78  1.13  0.93  0.52  0.89  0.92  0.85
# 2018-05-20 10:00  0.48  0.41  0.36  0.75  1.10  0.88  0.49  0.84  0.84  0.79
# 2018-05-20 11:00  0.48  0.41  0.31  0.71  1.07  0.84  0.46  0.79  0.77  0.73
# 2018-05-20 12:00  0.48  0.42  0.26  0.68  1.04  0.79  0.44  0.73  0.70  0.67
#
# code              ...    S42   S43   S44   S45   S46   S47   S48   S49   S50  \
# 2018-05-20 08:00  ...   0.60  0.29  0.32  0.13  0.09  0.11  0.17  0.22  0.59
# 2018-05-20 09:00  ...   0.65  0.29  0.33  0.13  0.09  0.10  0.15  0.22  0.58
# 2018-05-20 10:00  ...   0.71  0.29  0.34  0.14  0.09  0.10  0.15  0.23  0.58
# 2018-05-20 11:00  ...   0.77  0.29  0.35  0.15  0.09  0.09  0.15  0.22  0.57
# 2018-05-20 12:00  ...   0.83  0.30  0.36  0.17  0.09  0.09  0.15  0.22  0.56
#
# code               S51
# 2018-05-20 08:00  1.27
# 2018-05-20 09:00  1.26
# 2018-05-20 10:00  1.26
# 2018-05-20 11:00  1.25
# 2018-05-20 12:00  1.24
#
# [5 rows x 213 columns]

# %% [markdown]
# ### 3 提取每一列

# %% [markdown]
# * 遍历数据的每一行

# %%
def create_temp_df(df_convert_1,columns_key,nowday):
    df_new=pd.DataFrame(df_convert_1.loc[:,columns_key])    
#     print(df_new)
    df_new['code']=columns_key
    df_new['date']=nowday
    df_new=df_new.reset_index()
    df_new=df_new.rename(columns={'index':'tdate'})
    df_new=df_new.rename(columns={columns_key:'hs'})
#     print(df_new)
    return df_new

# %%
df_merage=pd.DataFrame(columns=['tdate','hs','code','date'])
for val in df_convert_1.columns.values:
    df_temp=create_temp_df(df_convert_1,val,'2018-03-13')
#     print(df_temp)
    df_merage=df_merage.append(df_temp)

# %%
df_merage.head()
# Out:
#               tdate    hs code        date
# 0  2018-05-20 08:00  0.48  N01  2018-03-13
# 1  2018-05-20 09:00  0.48  N01  2018-03-13
# 2  2018-05-20 10:00  0.48  N01  2018-03-13
# 3  2018-05-20 11:00  0.48  N01  2018-03-13
# 4  2018-05-20 12:00  0.48  N01  2018-03-13

# %% [markdown]
# ### 4 数据入库

# %% [markdown]
# #### 4.1 修改列的类型

# %%
df_merage.dtypes
# Out:
# tdate     object
# hs       float64
# code      object
# date      object
# dtype: object

# %%
df_merage['tdate']=df_merage['tdate'].astype('datetime64[ns]')
df_merage['date']=df_merage['date'].astype('datetime64[ns]')
df_merage.dtypes
# Out:
# tdate    datetime64[ns]
# hs              float64
# code             object
# date     datetime64[ns]
# dtype: object
