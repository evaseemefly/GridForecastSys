# %%
import numpy as np
import pandas as pd
import os
import sys
import datetime

# %% [markdown]
# ### 1 读取预报文件

# %%
targetPath=r""
data=pd.read_table("StormTide_20180709.txt")

# %%
data
# Out:
#            2018-07-09 08:00  2018-07-09 09:00  2018-07-09 10:00  \
# N01 SURGE              0.36              0.35              0.34
#     TIDE               3.43              3.58              3.73
# N02 SURGE              0.36              0.35              0.34
#     TIDE               3.43              3.58              3.73
# N03 SURGE              0.36              0.35              0.34
#     TIDE               3.43              3.58              3.73
#
#            2018-07-09 11:00  2018-07-09 12:00  2018-07-09 13:00  \
# N01 SURGE              0.33              0.33              0.32
#     TIDE               3.86              3.97              4.07
# N02 SURGE              0.33              0.33              0.32
#     TIDE               3.86              3.97              4.07
# N03 SURGE              0.33              0.33              0.32
#     TIDE               3.86              3.97              4.07
#
# ...

# %%
columns_date=data.iloc[0]
columns_date.head()
# Out:
# Unnamed: 0            N01
# Unnamed: 1          SURGE
# 2018-07-09 08:00     0.36
# 2018-07-09 09:00     0.35
# 2018-07-09 10:00     0.34
# Name: 0, dtype: object
